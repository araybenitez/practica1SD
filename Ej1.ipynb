# %%
import pyspark
from pyspark import SparkContext

sc=SparkContext.getOrCreate()

data = sc.textFile("work/calidad_aire_datos_meteo_mes.csv")

cabecera = data.first()



res = (data
       .filter(lambda x: x!= cabecera).map(lambda line: line.split(";"))
       .filter(lambda x: x[0] == 28)
       .filter(lambda x: x[3] == 83)
       .replace(",",".")
       for i in range(9,57)
        if i % 2 != 0
            .filter(lambda x: x[i], V)

        .collect()
        )
dias = data.count()
print("resultado:", dias)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 23
#       8 cabecera = data.first()
#      12 res = (data
#      13        .filter(lambda x: x!= cabecera).map(lambda line: line.split(";"))
#      14        .filter(lambda x: x[0] == 28)
#    (...)     21         .collect()
#      22         )
# ---> 23 dias = res.count()
#      24 print("resultado:", dias)
#
# AttributeError: 'generator' object has no attribute 'count'
